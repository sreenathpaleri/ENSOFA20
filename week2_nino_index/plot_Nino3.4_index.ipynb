# %% [markdown]
# #### ENSO Directed study Fall 2020
# original code from Taylor McHone and Karimar Ledesma-Maldonado (CSU), <br>
# last updated 10/19/2020

# %%
from pylab import *
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from datetime import datetime
from math import pi
import matplotlib.pyplot as plt

# %%
dflong=pd.read_csv("nino34long.csv")

# %%
df = pd.read_csv("nino34.csv")
del df['Column1']
df = df.set_index('Column2')
df.columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df.index.names = ['Year']
df=df.drop([1948, 1949])
df['Dec'].iloc[-1]=None
df['Nov'].iloc[-1]=None
df['Oct'].iloc[-1]=None

# %%
#EP
nsvn = df.loc[1997]
neit = df.loc[1998]

#CP
ofour = df.loc[2004]
ofive = df.loc[2005]

#normal
one = df.loc[1993]
two = df.loc[1994]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, gridspec_kw={'hspace': .5, 'wspace': .025})
f.suptitle("Nino 3.4 Index", size=15)
f.set_figheight(5)
f.set_figwidth(15)
ax1.plot(nsvn)
ax1.set_ylim(24.8, 29.3)
ax1.set_title('1997')
ax2.plot(neit)
ax2.set_title('1998')
# Out:
# Text(0.5, 1.0, '1998')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, gridspec_kw={'hspace': .5, 'wspace': .025})
f.set_figheight(5)
f.suptitle("Nino 3.4 Index", size=15)
f.set_figwidth(15)
ax1.plot(one)
ax1.set_ylim(24.8, 29.3)
ax1.set_title('1993')
ax2.plot(two)
ax2.set_title('1994')
# Out:
# Text(0.5, 1.0, '1994')

# %%
cols = []
for col in range(len(df)):
    lis = list(df.iloc[col].values)
    for val in lis:
        cols.append(val)
df = pd.DataFrame(cols)
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(10)
ax.plot(df)

# %%
nums = []
matplotlib.rcParams["font.size"] = 16
for i in range(852):
    nums.append(1950 + (i *(1/12)))
df['Year']=nums
ax = df.plot.line(x="Year", figsize=(20, 10), legend=False)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_title('Nino 3.4 Index')
plt.xticks(np.arange(1950, 2020, 5));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c48b021616ad> in <module>
#       3 for i in range(852):
#       4     nums.append(1950 + (i *(1/12)))
# ----> 5 df['Year']=nums
#       6 ax = df.plot.line(x="Year", figsize=(20, 10), legend=False)
#       7 ax.spines["top"].set_visible(False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3759
#    3760             # turn me into an ndarray
# -> 3761             value = sanitize_index(value, self.index)
#    3762             if not isinstance(value, (np.ndarray, Index)):
#    3763                 if isinstance(value, list) and len(value) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (852) does not match length of index (1704)

# %%
file=np.loadtxt(fname='nina34.data', delimiter=', ')
#'J','F', 'M','A' are the name of the column in the dataset in this case the letter of the month
df=pd.DataFrame(f, columns= ['J','F', 'M','A','My','Jn', 'Jl','Ag''S','O', 'N','D']) 
#'J','F', 'M','A' are the name of the column in the dataset

#change freq appropiate for the dataset
df['Date']=pd.date_range('1948', '2020', freq='50L') #frequency=20Hz~ 0.05s~50L
df.set_index('Date', inplace=True)

# Example to add column
#df['Temp(K)']=df['T']+273 # converting Temperature to Kelvin
#df['Temp(K)'].plot(title ="Temperature versus time", legend=True)
#savefig('TempK.png')

#to plot 3 variables in the same figure
#df[['J','F', 'M']].plot(title ="", legend=True)
#savefig('winds.png')
#show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-b6327d540640> in <module>
# ----> 1 file=np.loadtxt(fname='nina34.data', delimiter=', ')
#       2 #'J','F', 'M','A' are the name of the column in the dataset in this case the letter of the month
#       3 df=pd.DataFrame(f, columns= ['J','F', 'M','A','My','Jn', 'Jl','Ag''S','O', 'N','D'])
#       4 #'J','F', 'M','A' are the name of the column in the dataset
#       5
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: nina34.data not found.
